# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import mpl_toolkits
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import GradientBoostingRegressor

# %%
data=pd.read_csv('datasets/kc-house-data.csv')

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# ## Most common houuse

# %%
plt.figure(figsize=(10,8))
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('No of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')

sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %% [markdown]
# #### Observations

# %% [markdown]
# 3 bedroom houses are most commonly sold followed by 4 bedroom. So how is it useful ? For a builder having this data , He can make a new building with more 3 and 4 bedroom’s to attract more buyers.

# %% [markdown]
# ## Visualizing the location of the houses based on latitude and longitude

# %%
plt.figure(figsize=(10,8))
sns.jointplot(x=data.lat.values,y=data.long.values,size=10)
plt.title('location and how the houses are placed.')
plt.xlabel('Longitued ',fontsize=12)
plt.ylabel('Latitude ',fontsize=12)
plt.show()

sns.despine
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %% [markdown]
# ### How common factors are affecting the price of the houses ?

# %%
plt.figure(figsize=(10,8))
plt.scatter(data.price,data.sqft_living)
plt.title('price vs sqft_living')
plt.xlabel('Sqft living ',fontsize=12)
plt.ylabel('Price ',fontsize=12)
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,8))
plt.scatter(data.price,data.long)
plt.title('price vs Location of the area')
plt.xlabel('Location ',fontsize=12)
plt.ylabel('Price ',fontsize=12)
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,8))
plt.scatter(data.bedrooms,data.price)
plt.title('price vs Bedrooms')
plt.xlabel('Location ',fontsize=12)
plt.ylabel('Price ',fontsize=12)
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,8))
plt.scatter(data.condition,data.price)
plt.title('price vs condition')
plt.xlabel('condition ',fontsize=12)
plt.ylabel('Price ',fontsize=12)
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %% [markdown]
# ## Linear Regression :-

# %% [markdown]
# ### Regression works on the line equation , y=mx+c , trend line is set through the data points to predict the outcome.

# %%
reg=LinearRegression()

# %%
labels=data['price']
conv_dates=[1 if values ==2014 else 0 for values in data.date ]
data['date']=conv_dates
train1=data.drop(['id','price'],axis=1)

# %%
x_train,x_test,y_train,y_test =train_test_split(train1,labels,test_size=0.10,random_state=2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.score(x_test,y_test)
# Out:
# 0.7320342760357132

# %% [markdown]
# ## Lets use train data and test data , train data to train our machine and test data to see if it has learnt the data well or not

# %% [markdown]
# #### Gradient boosting regression  (GBM) algorithm

# %%
est=GradientBoostingRegressor(n_estimators=2000,max_depth=1).fit(X,y)
for pred in est.staged_prdict(X):
    plt.plot(X[:,0],pred,color='r', alpha=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-ca544376a32b> in <module>()
# ----> 1 est=GradientBoostingRegressor(n_estimators=2000,max_depth=1).fit(X_train, y_train)
#       2 for pred in est.staged_prdict(X_train):
#       3     plt.plot(X_train[:,0],pred,color='r', alpha=0.1)
#
# NameError: name 'X_train' is not defined
